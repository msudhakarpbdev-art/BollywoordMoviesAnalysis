# %%
# Bollywood Movies Analaysis Notebook
'''
We have BollywoodRanking.csv which will loaded into the Notebook and analysis is done through Python Language.
'''
'''
Following are the Methods & Functions used for analysis and their details

First import library files into the notebook
panda as pd
numpy as np
matplotlib.pyplot as plt
seaborn as sb

pd.read_csv
'''

# %% [markdown]
# 1. Import Libraries

# %%
# Data Processing
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# Read CSV File and Load into df (data frame)
# dataframe taken as df
df = pd.read_csv("BollywoodActorRanking.csv")
# Out:
#    actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0      373        Aamir Khan          11       1170              9.44862
# 1      374    Shah Rukh Khan          23       2000              7.55009
# 2      375       Salman Khan          36       2340              5.40217
# 3      376      Katrina Kaif          17       1640              8.48082
# 4      377  Deepika Padukone          16       1080              5.64674
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0     2460000               7.34283          10.00000
# 1     2670000               7.88458           9.22674
# 2     3490000              10.00000           9.20821
# 3     2120000               6.46570           8.94852
# 4     3000000               8.73591           8.62716

# %%
# Methods to read
''' 
read_csv()
read_excel()
'''

# following are the number of methods to check on the data like 
'''
df.head()
df.tail()
df.info()
'''
# following are used for finding necessary null, duplicate or useful
'''
isnull()/isna()     : Detects missing (null) values in the data.
dropna()            : Removes rows or columns that contain missing values.
fillna()            : Fills missing values with a specified value or method (e.g., mean, median, mode).
drop_duplicates()   : Identifies and removes duplicate entries from the dataset.
rename()            : Renames columns for better readability and consistency.
astype()            : Converts a column to a different data type (e.g., converting a string to a numeric or datetime format).
'''

# %%
# df.head()     - First Top Rows
# df.tail()     - Last Top Rows
# df.info()     - Information on each column type and null-content
# df.describe() - Describe each column count, mean, std, 25%, 50%, 75%, max
# df.describe(include='all')    - Describe each column count, unique, top, freq, mean, std, 25%, 50%, 75%, max
# df.sample(5)  - Radom Values will be displayed
# df.columns    - displays columns in list
# df.dtypes     - column & datatypes
# df.shape      - returns a tuple representing the dimensions of the DataFrame (number of rows, number of columns)
# df.isnull().sum() - Count missing values
# df.isnull().values.any()  - Check if any missing values exist
# df['column_name'].unique()    - Unique Values    
# df['column_name'].nunique()   - Count unique values
# df['column_name'].value_counts()  - Value Counts (Frequency)
# df[df['Age'] > 30]    -   Filtering Data
# df[(df['Age'] > 30) & (df['Salary'] > 50000)] - Filtering Data Multiple conditions
# df.groupby('Department')['Salary'].mean() - Group By Analysis
# df.groupby('Department').agg({'Salary':'mean','Age':'max'})   -   Group By Analysis Multiple aggregation
# df.sort_values(by='Salary', ascending=False)  -   Sorting Data
# Correlation Analysis
# df.corr() - Correlation Analysis
# printing following
'''
print(df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
print(df.head())
'''

# %%
# Basic Visualization

import matplotlib.pyplot as plt
df['ratingSum'].hist()
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#df = pd.read_csv("file.csv")
# Out:
# (301, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   actorId               301 non-null    int64
#  1   actorName             301 non-null    object
#  2   movieCount            301 non-null    int64
#  3   ratingSum             301 non-null    int64
#  4   normalizedMovieRank   299 non-null    float64
#  5   googleHits            301 non-null    int64
#  6   normalizedGoogleRank  189 non-null    float64
#  7   normalizedRating      301 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.9+ KB
# None
#           actorId  movieCount    ratingSum  normalizedMovieRank    googleHits  \
# count  301.000000  301.000000   301.000000           299.000000  3.010000e+02
# mean   523.000000   10.232558   419.136213             2.768970  3.741886e+05
# ...
